# %%
import numpy as np
import gym
import beer_game_env
import cloudpickle
import gym
from gym import error, spaces
from gym.utils import seeding
import itertools
from collections import deque
import numpy as np

env = gym.make('BeerGame-v0', n_agents=4, env_type='classical')

# %%
if __name__ == '__main__':
    env = gym.make('BeerGame-v0', n_agents=4, env_type='classical')
    start_state = env.reset()
    env.render()
    done = False
    while not done:
        actions = np.random.uniform(0, 4, size=4)
        actions = np.ceil(actions)
        next_state, rewards, done, _ = env.step(actions)
        env.render()
# Out:
# ------------------------------TURN 00------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 50
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 50
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 50
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 9
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 10
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 10
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 10
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([10, 11])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([10, 4])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([10, 10])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 10
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 10
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 10
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 10
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 51
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 50
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 50
#
# ------------------------------TURN 01------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 51
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 50
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 50
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 11
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 10
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 10
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 10
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([11, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([10, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 10
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 10
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 10
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 10
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([10, 4])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 50
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 50
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 50
#
# ------------------------------TURN 02------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 50
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 50
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 50
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 9
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 11
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 10
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 10
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 10
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 10
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 10
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([10, 11])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([10, 4])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([10, 10])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4, 4.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 51
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 49
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 56
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 50
#
# ------------------------------TURN 03------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 51
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 49
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 56
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 50
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 8
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 10
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 10
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 10
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([11, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([10, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 53
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 63.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 50.0
#
# ------------------------------TURN 04------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 53
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 63.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 50.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 9
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 11
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 10
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 4.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 55
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 53.0
#
# ------------------------------TURN 05------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 55
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 53.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 12
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([4.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 46.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 53.0
#
# ------------------------------TURN 06------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 46.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 53.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 5
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 45.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 07------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 45.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 56.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 8
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([1.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 4.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 40.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 08------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 40.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 72.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 2
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 41.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 09------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 41.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 7
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([3.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 38.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 68.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 10------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 38.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 68.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 13
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 3.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 26.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 53.0
#
# ------------------------------TURN 11------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 26.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 53.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 4
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 25.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 12------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 25.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 10
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 3.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 18.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 13------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 18.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 5
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 16.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 14------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 16.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 71.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 8
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([1.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([2.0, 4.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 11.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 73.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 15------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 11.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 73.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 5
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : 8.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 16------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : 8.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 14
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 1.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 4.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -2.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 48.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 68.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 17------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -2.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 48.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 68.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 3
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -4.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 66.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 56.0
#
# ------------------------------TURN 18------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -4.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 49.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 66.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 56.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 5
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([3.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -6.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 58.0
#
# ------------------------------TURN 19------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -6.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 58.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 12
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 3.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -15.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 55.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 56.0
#
# ------------------------------TURN 20------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -15.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 55.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 56.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 4
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 4.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -18.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 58.0
#
# ------------------------------TURN 21------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -18.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 54.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 58.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 10
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([3.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 3.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -27.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 59.0
#
# ------------------------------TURN 22------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -27.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 59.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 6
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 3.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -31.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 60.0
#
# ------------------------------TURN 23------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -31.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 60.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 10
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([2.0, 4.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -39.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 58.0
#
# ------------------------------TURN 24------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -39.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 52.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 58.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 9
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 4.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 1.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 1.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 3.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([4.0, 4.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 4.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -46.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 66.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 57.0
#
# ------------------------------TURN 25------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -46.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 66.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 57.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 15
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([1.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([1.0, 2.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([4.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -57.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 57.0
#
# ------------------------------TURN 26------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -57.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 67.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 57.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 5
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 1.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 4.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 2.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 4.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 3.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([2.0, 1.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 4.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -58.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 56.0
#
# ------------------------------TURN 27------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -58.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 56.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 6
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 2.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([4.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 1.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 1.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([1.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([4.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -62.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 28------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -62.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 53.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 9
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 2.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([3.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([3.0, 1.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([1.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 1.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 4.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 2.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([2.0, 4.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -70.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 51.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 55.0
#
# ------------------------------TURN 29------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -70.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 51.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 70.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 55.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 4
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 3.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([2.0, 4.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([3.0, 4.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([1.0, 4.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([2.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 2.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([2.0, 3.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([4.0, 1.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -71.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 54.0
#
# ------------------------------TURN 30------------------------------
# [   RETAILER    ]의 기초재고(beginning stocks) 상태 : -71.0
# [  WHOLESALER   ]의 기초재고(beginning stocks) 상태 : 50.0
# [  DISTRIBUTOR  ]의 기초재고(beginning stocks) 상태 : 69.0
# [ MANUFACTURER  ]의 기초재고(beginning stocks) 상태 : 54.0
# .
#      [   RETAILER    ]의 주문수령(inbound orders) 상태 : 4
#      [  WHOLESALER   ]의 주문수령(inbound orders) 상태 : 2.0
#      [  DISTRIBUTOR  ]의 주문수령(inbound orders) 상태 : 3.0
#      [ MANUFACTURER  ]의 주문수령(inbound orders) 상태 : 1.0
# .
#      [   RETAILER    ]의 주문요청(outbound orders) 상태 : deque([4.0, 2.0])
#      [  WHOLESALER   ]의 주문요청(outbound orders) 상태 : deque([4.0, 3.0])
#      [  DISTRIBUTOR  ]의 주문요청(outbound orders) 상태 : deque([4.0, 3.0])
#      [ MANUFACTURER  ]의 주문요청(outbound orders) 상태 : deque([3.0])
# .
#      [   RETAILER    ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  WHOLESALER   ]의 배송수령(inbound shipments) 상태 : 3.0
#      [  DISTRIBUTOR  ]의 배송수령(inbound shipments) 상태 : 2.0
#      [ MANUFACTURER  ]의 배송수령(inbound shipments) 상태 : 4.0
# .
#      [   RETAILER    ]의 배송발송(outbound shipments) 상태 : 해당 사항 없음
#      [  WHOLESALER   ]의 배송발송(outbound shipments) 상태 : deque([3.0, 2.0])
#      [  DISTRIBUTOR  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 3.0])
#      [ MANUFACTURER  ]의 배송발송(outbound shipments) 상태 : deque([3.0, 1.0])
#      [   SUPPLIER    ]의 배송발송(outbound shipments) 상태 : deque([1.0, 2.0])
# .
# [   RETAILER    ]의 기말재고(ending stocks) 상태 : -72.0
# [  WHOLESALER   ]의 기말재고(ending stocks) 상태 : 51.0
# [  DISTRIBUTOR  ]의 기말재고(ending stocks) 상태 : 68.0
# [ MANUFACTURER  ]의 기말재고(ending stocks) 상태 : 57.0
